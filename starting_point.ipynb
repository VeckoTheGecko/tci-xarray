# %%
import xarray as xr

# %%
help(xr.tutorial.open_dataset)

# %%
ds = xr.tutorial.open_dataset("air_temperature")

# %%
ds.air.shape

# %%
ds.air

# %%
ds.air.interp(dict(lat=70.3, lon=201, time="2013-01-03"))
